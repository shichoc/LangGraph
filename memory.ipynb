# %% [markdown]
# # LangGraph Memory 示範
#
# 這份 notebook 使用 `MemorySaver` 儲存對話狀態。只要使用相同的 `thread_id`，LLM 就能讀到先前的訊息；不同的 `thread_id` 則會擁有彼此獨立的記憶。

# %% [markdown]
# ## 1. Import libraries

# %%
import os

from IPython.display import Image, display
from langchain_core.messages import HumanMessage
from langchain_openai import ChatOpenAI
from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import MessagesState, StateGraph, START, END
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 6
#       4 from IPython.display import Image, display
#       5 from langchain_core.messages import HumanMessage
# ----> 6 from langchain_openai import ChatOpenAI
#       7 from langgraph.checkpoint.memory import MemorySaver
#       8 from langgraph.graph import MessagesState, StateGraph, START, END
#
# File ~\scoop\apps\python\current\Lib\site-packages\langchain_openai\__init__.py:4
#       1 """Module for OpenAI integrations."""
#       3 from langchain_openai._version import __version__
# ----> 4 from langchain_openai.chat_models import AzureChatOpenAI, ChatOpenAI
#       5 from langchain_openai.chat_models._client_utils import StreamChunkTimeoutError
#       6 from langchain_openai.embeddings import AzureOpenAIEmbeddings, OpenAIEmbeddings
#
# File ~\scoop\apps\python\current\Lib\site-packages\langchain_openai\chat_models\__init__.py:3
#       1 """Module for OpenAI chat models."""
# ----> 3 from langchain_openai.chat_models.azure import AzureChatOpenAI
#       4 from langchain_openai.chat_models.base import ChatOpenAI
#       6 __all__ = ["AzureChatOpenAI", "ChatOpenAI"]
#
# File ~\scoop\apps\python\current\Lib\site-packages\langchain_openai\chat_models\azure.py:10
#       7 from collections.abc import AsyncIterator, Awaitable, Callable, Iterator
#       8 from typing import TYPE_CHECKING, Any, Literal, TypeAlias, TypeVar
# ---> 10 import openai
#      11 from langchain_core.language_models import LanguageModelInput
#      12 from langchain_core.language_models.chat_models import LangSmithParams
#
# File ~\scoop\apps\python\current\Lib\site-packages\openai\__init__.py:109
#     107 from .lib.bedrock import BedrockOpenAI as BedrockOpenAI, AsyncBedrockOpenAI as AsyncBedrockOpenAI
#     108 from .lib._old_api import *
# --> 109 from .lib.streaming import (
#     110     AssistantEventHandler as AssistantEventHandler,
#     111     AsyncAssistantEventHandler as AsyncAssistantEventHandler,
#     112 )
#     114 _setup_logging()
#     116 # Update the __module__ attribute for exported symbols so that
#     117 # error messages point to this module instead of the module
#     118 # it was originally defined in, e.g.
#     119 # openai._exceptions.NotFoundError -> openai.NotFoundError
#
# File ~\scoop\apps\python\current\Lib\site-packages\openai\lib\streaming\__init__.py:1
# ----> 1 from ._assistants import (
#       2     AssistantEventHandler as AssistantEventHandler,
#       3     AssistantEventHandlerT as AssistantEventHandlerT,
#       4     AssistantStreamManager as AssistantStreamManager,
#       5     AsyncAssistantEventHandler as AsyncAssistantEventHandler,
#       6     AsyncAssistantEventHandlerT as AsyncAssistantEventHandlerT,
#       7     AsyncAssistantStreamManager as AsyncAssistantStreamManager,
#       8 )
#
# File ~\scoop\apps\python\current\Lib\site-packages\openai\lib\streaming\_assistants.py:13
#      11 from ..._models import construct_type
#      12 from ..._streaming import Stream, AsyncStream
# ---> 13 from ...types.beta import AssistantStreamEvent
#      14 from ...types.beta.threads import (
#      15     Run,
#      16     Text,
#    (...)     22     MessageContentDelta,
#      23 )
#      24 from ...types.beta.threads.runs import RunStep, ToolCall, RunStepDelta, ToolCallDelta
#
# File ~\scoop\apps\python\current\Lib\site-packages\openai\types\beta\__init__.py:8
#       6 from .assistant import Assistant as Assistant
#       7 from .beta_tool import BetaTool as BetaTool
# ----> 8 from .beta_response import BetaResponse as BetaResponse
#       9 from .function_tool import FunctionTool as FunctionTool
#      10 from .assistant_tool import AssistantTool as AssistantTool
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1322, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:1262, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1559, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1533, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1632, in find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:152, in _path_stat(path)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 2. 建立 LLM
#
# 請先在系統環境變數中設定 `OPENAI_API_KEY`。如果課程環境使用自訂 API endpoint，也可以設定 `OPENAI_BASE_URL`。

# %%
llm_options = {
    "api_key": os.environ["OPENAI_API_KEY"],
    "model": os.getenv("OPENAI_MODEL", "gpt-4o-mini"),
    "temperature": 0.0,
}

# 如果有設定自訂 endpoint，就將它加入 ChatOpenAI 的參數。
if os.getenv("OPENAI_BASE_URL"):
    llm_options["base_url"] = os.getenv("OPENAI_BASE_URL")

llm = ChatOpenAI(**llm_options)

# %% [markdown]
# ## 3. 建立具有記憶功能的 LangGraph
#
# `MessagesState` 會累積訊息；`MemorySaver` 則依照 `thread_id` 保存每次執行後的 checkpoint。

# %%
def chatbot(state: MessagesState):
    response = llm.invoke(state["messages"])
    return {"messages": [response]}


workflow = StateGraph(MessagesState)
workflow.add_node("chatbot", chatbot)
workflow.add_edge(START, "chatbot")
workflow.add_edge("chatbot", END)

memory = MemorySaver()
graph = workflow.compile(checkpointer=memory)

# %%
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ## 4. 準備對話函式
#
# 每次只傳入最新問題。過去的訊息不需要由我們手動重傳，checkpointer 會根據 `thread_id` 自動取回。

# %%
def ask(question: str, thread_id: str = "demo-user") -> str:
    config = {"configurable": {"thread_id": thread_id}}
    result = graph.invoke(
        {"messages": [HumanMessage(content=question)]},
        config=config,
    )
    answer = result["messages"][-1].content
    print(f"You: {question}\nAI: {answer}")
    return answer

# %% [markdown]
# ## 5. 測試：讓 LLM 記住先前說過的內容

# %%
ask("請記住：我的名字是小明，我最喜歡的寶可夢是皮卡丘。", thread_id="conversation-1")

# %%
# 沒有再次提供名字與寶可夢，模型仍可從同一個 thread 的記憶回答。
ask("我剛才說我的名字是什麼？最喜歡的寶可夢又是誰？", thread_id="conversation-1")

# %% [markdown]
# ## 6. 查看記憶體中的訊息
#
# 可以直接讀取目前 checkpoint，確認 `conversation-1` 已保存完整對話。

# %%
config_1 = {"configurable": {"thread_id": "conversation-1"}}
current_state = graph.get_state(config_1)

for message in current_state.values["messages"]:
    print(f"{message.type}: {message.content}")

# %% [markdown]
# ## 7. 對照：不同 thread 不共享記憶
#
# 下面改用全新的 `conversation-2`。因為它沒有前面的 checkpoint，模型應該不知道使用者的名字與喜好。

# %%
ask("我的名字是什麼？我最喜歡哪一隻寶可夢？", thread_id="conversation-2")

# %% [markdown]
# ## 重點整理
#
# - 相同 `thread_id`：延續先前訊息，適合多輪對話。
# - 不同 `thread_id`：各自保存狀態，可隔離不同使用者或不同對話。
# - `MemorySaver` 只保存在目前 Python 程序的記憶體中；kernel 重啟後資料就會消失。正式系統可改用資料庫型 checkpointer，讓記憶持久保存。
